# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, recall_score, precision_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, mean_squared_error
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
import gdown

# %%
# Download data from Google Sheets
url = "https://docs.google.com/spreadsheets/d/1HsoBkbMjuH6vd1zR9Wwjm_fp5QBR0SruYb5x7yy-J74/export?format=csv&gid=1708419967"
output = "data.csv"
gdown.download(url, output, quiet=False)

# Load data
df = pd.read_csv("data.csv")
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1HsoBkbMjuH6vd1zR9Wwjm_fp5QBR0SruYb5x7yy-J74/export?format=csv&gid=1708419967
# To: /content/data.csv
# 4.57kB [00:00, 7.03MB/s]
#        Nama  Penghasilan Bulanan   Pengeluaran Bulanan  Tabungan Bulanan   \
# 0    Amanda         Rp 5,500,000         Rp 6,000,000         Rp 500,000
# 1  Berlinda         Rp 6,200,000         Rp 7,500,000       Rp 1,300,000
# 2     Bunga         Rp 7,800,000         Rp 5,800,000       Rp 2,000,000
# 3      Cici         Rp 8,500,000         Rp 6,500,000       Rp 2,000,000
# 4    Cintya         Rp 9,100,000         Rp 7,200,000       Rp 1,900,000
#
#   Tingkat Tabungan Rasio Pengeluaran Rasio Tabungan  Hasil Analis  \
# 0            9.09%           109.09%         12.00%             0
# 1           20.97%           120.97%          5.77%             0
# 2           25.64%            74.36%          2.90%             2
# 3           23.53%            76.47%          3.25%             1
# 4           20.88%            79.12%          3.79%             1
#
#   Kesehatan Finansial
# 0         Kurang Baik
# 1         Kurang Baik
# 2         Sangat Baik
# 3                Baik
# 4                Baik

# %%
# Preprocess data
df[' Penghasilan Bulanan '] = df[' Penghasilan Bulanan '].str.replace('Rp ', '').str.replace(',', '').astype(float) / 1e6
df[' Pengeluaran Bulanan'] = df[' Pengeluaran Bulanan'].str.replace('Rp ', '').str.replace(',', '').astype(float) / 1e6
df[' Tabungan Bulanan '] = df[' Tabungan Bulanan '].str.replace('Rp ', '').str.replace(',', '').astype(float) / 1e6

# Select relevant columns
df = df.loc[:, [' Penghasilan Bulanan ', ' Pengeluaran Bulanan', ' Tabungan Bulanan ', 'Kesehatan Finansial']]

print(df.head())
df.to_csv('data.csv')
# Out:
#     Penghasilan Bulanan    Pengeluaran Bulanan   Tabungan Bulanan   \
# 0                    5.5                   6.0                 0.5
# 1                    6.2                   7.5                 1.3
# 2                    7.8                   5.8                 2.0
# 3                    8.5                   6.5                 2.0
# 4                    9.1                   7.2                 1.9
#
#   Kesehatan Finansial
# 0         Kurang Baik
# 1         Kurang Baik
# 2         Sangat Baik
# 3                Baik
# 4                Baik

# %%
# Memuat file CSV ke dalam DataFrame pandas
file_path = '/content/data.csv'
df = pd.read_csv(file_path)

# Mengubah label 'Kesehatan Finansial' menjadi angka
LABEL2INDEX = {'Kurang Baik': 0, 'Baik': 1, 'Sangat Baik': 2}
INDEX2LABEL = {v: k for k, v in LABEL2INDEX.items()}

df['Kesehatan Finansial'] = df['Kesehatan Finansial'].apply(lambda lab: LABEL2INDEX[lab])

# Split into features and target
X = df[[' Penghasilan Bulanan ', ' Pengeluaran Bulanan', ' Tabungan Bulanan ']]
y = df['Kesehatan Finansial']

# # Encode target variable
# le = LabelEncoder()
# y = le.fit_transform(y)

# Scale features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Define K-fold cross-validation
kf = KFold(n_splits=3, shuffle=True, random_state=42)
# Menyimpan hasil dari setiap fold
fold_accuracies = []
fold_f1_scores = []
fold_precision_scores = []
fold_recall_scores = []
histories = []

# Model initialization (outside the loop)
best_model = None
best_accuracy = 0

# %%
for fold, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Training fold {fold + 1}")

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Membangun model neural network
    model = Sequential()
    model.add(Dense(32, input_dim=3, activation='relu'))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(3, activation='softmax'))

    # Compile model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Melatih model dan menyimpan history
    history = model.fit(X_train, y_train, epochs=50, batch_size=10, verbose=1)
    histories.append(history)

    # Prediksi pada set pengujian
    y_pred = np.argmax(model.predict(X_test), axis=-1)

    # Menghitung metrik evaluasi
    accuracy = accuracy_score(y_test, y_pred)
    fold_accuracies.append(accuracy)
    fold_f1_scores.append(f1_score(y_test, y_pred, average='weighted'))
    fold_precision_scores.append(precision_score(y_test, y_pred, average='weighted'))
    fold_recall_scores.append(recall_score(y_test, y_pred, average='weighted'))



    # Save the best model
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_model = model

# Rata-rata hasil dari semua fold
print(f'Average Accuracy: {np.mean(fold_accuracies)}')
print(f'Average F1 Score: {np.mean(fold_f1_scores)}')
print(f'Average Precision Score: {np.mean(fold_precision_scores)}')
print(f'Average Recall Score: {np.mean(fold_recall_scores)}')
# Out:
# Training fold 1
# Epoch 1/50
# 4/4 [==============================] - 1s 4ms/step - loss: 1.0790 - accuracy: 0.4375
# Epoch 2/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0307 - accuracy: 0.7188
# Epoch 3/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9871 - accuracy: 0.7812
# Epoch 4/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9460 - accuracy: 0.8125
# Epoch 5/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9066 - accuracy: 0.8750
# Epoch 6/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8692 - accuracy: 0.8125
# Epoch 7/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8326 - accuracy: 0.8125
# Epoch 8/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7990 - accuracy: 0.8125
# Epoch 9/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7672 - accuracy: 0.8125
# Epoch 10/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7356 - accuracy: 0.8125
# Epoch 11/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7061 - accuracy: 0.8125
# Epoch 12/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6789 - accuracy: 0.8125
# Epoch 13/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6525 - accuracy: 0.8125
# Epoch 14/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6281 - accuracy: 0.8125
# Epoch 15/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6044 - accuracy: 0.8125
# Epoch 16/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5830 - accuracy: 0.8125
# Epoch 17/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5611 - accuracy: 0.8125
# Epoch 18/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5419 - accuracy: 0.8125
# Epoch 19/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5247 - accuracy: 0.8125
# Epoch 20/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5101 - accuracy: 0.8125
# Epoch 21/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4957 - accuracy: 0.8125
# Epoch 22/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4839 - accuracy: 0.8125
# Epoch 23/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4723 - accuracy: 0.8125
# Epoch 24/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4620 - accuracy: 0.8125
# Epoch 25/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4521 - accuracy: 0.8125
# Epoch 26/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4429 - accuracy: 0.8125
# Epoch 27/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4355 - accuracy: 0.8125
# Epoch 28/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4259 - accuracy: 0.8125
# Epoch 29/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4196 - accuracy: 0.8125
# Epoch 30/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4136 - accuracy: 0.8125
# Epoch 31/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4070 - accuracy: 0.8125
# Epoch 32/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4017 - accuracy: 0.8125
# Epoch 33/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3966 - accuracy: 0.8125
# Epoch 34/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3906 - accuracy: 0.8125
# Epoch 35/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3858 - accuracy: 0.8125
# Epoch 36/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3808 - accuracy: 0.8125
# Epoch 37/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3761 - accuracy: 0.8125
# Epoch 38/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8125
# Epoch 39/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3674 - accuracy: 0.8125
# Epoch 40/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3633 - accuracy: 0.8125
# Epoch 41/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3596 - accuracy: 0.8125
# Epoch 42/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3546 - accuracy: 0.8125
# Epoch 43/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3517 - accuracy: 0.8750
# Epoch 44/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3470 - accuracy: 0.8750
# Epoch 45/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3438 - accuracy: 0.8750
# Epoch 46/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3398 - accuracy: 0.8750
# Epoch 47/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3361 - accuracy: 0.8750
# Epoch 48/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3328 - accuracy: 0.8750
# Epoch 49/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3284 - accuracy: 0.8750
# Epoch 50/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3250 - accuracy: 0.8750
# 1/1 [==============================] - 0s 52ms/step
# Training fold 2
# Epoch 1/50
# 4/4 [==============================] - 1s 3ms/step - loss: 1.1930 - accuracy: 0.1212
# Epoch 2/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1634 - accuracy: 0.1212
# Epoch 3/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1379 - accuracy: 0.1212
# Epoch 4/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1174 - accuracy: 0.2121
# Epoch 5/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0962 - accuracy: 0.2424
# Epoch 6/50
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0746 - accuracy: 0.3333
# Epoch 7/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0538 - accuracy: 0.3939
# Epoch 8/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0354 - accuracy: 0.5758
# Epoch 9/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0151 - accuracy: 0.6061
# Epoch 10/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9965 - accuracy: 0.5758
# Epoch 11/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9774 - accuracy: 0.5758
# Epoch 12/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9609 - accuracy: 0.5758
# Epoch 13/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9425 - accuracy: 0.5758
# Epoch 14/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9242 - accuracy: 0.6970
# Epoch 15/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9050 - accuracy: 0.7576
# Epoch 16/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8892 - accuracy: 0.7576
# Epoch 17/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8704 - accuracy: 0.7576
# Epoch 18/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8500 - accuracy: 0.8182
# Epoch 19/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8329 - accuracy: 0.8182
# Epoch 20/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8131 - accuracy: 0.8182
# Epoch 21/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7947 - accuracy: 0.8182
# Epoch 22/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7781 - accuracy: 0.8182
# Epoch 23/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7612 - accuracy: 0.8485
# Epoch 24/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7431 - accuracy: 0.8788
# Epoch 25/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7264 - accuracy: 0.8788
# Epoch 26/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7076 - accuracy: 0.8788
# Epoch 27/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6902 - accuracy: 0.8788
# Epoch 28/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6730 - accuracy: 0.8788
# Epoch 29/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6565 - accuracy: 0.8788
# Epoch 30/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6399 - accuracy: 0.8788
# Epoch 31/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6239 - accuracy: 0.8788
# Epoch 32/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6080 - accuracy: 0.8788
# Epoch 33/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5931 - accuracy: 0.8788
# Epoch 34/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5780 - accuracy: 0.8788
# Epoch 35/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5641 - accuracy: 0.8788
# Epoch 36/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5507 - accuracy: 0.8788
# Epoch 37/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5380 - accuracy: 0.8788
# Epoch 38/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5246 - accuracy: 0.8788
# Epoch 39/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5118 - accuracy: 0.9091
# Epoch 40/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4997 - accuracy: 0.9091
# Epoch 41/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4878 - accuracy: 0.9091
# Epoch 42/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4760 - accuracy: 0.9091
# Epoch 43/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4655 - accuracy: 0.9394
# Epoch 44/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4540 - accuracy: 0.9394
# Epoch 45/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4433 - accuracy: 0.9394
# Epoch 46/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4332 - accuracy: 0.9394
# Epoch 47/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4237 - accuracy: 0.9697
# Epoch 48/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4134 - accuracy: 0.9697
# Epoch 49/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4042 - accuracy: 0.9697
# Epoch 50/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3949 - accuracy: 0.9697
# 1/1 [==============================] - 0s 54ms/step
# Training fold 3
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 4/4 [==============================] - 1s 3ms/step - loss: 1.0386 - accuracy: 0.5455
# Epoch 2/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0024 - accuracy: 0.5455
# Epoch 3/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9692 - accuracy: 0.5455
# Epoch 4/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9396 - accuracy: 0.5758
# Epoch 5/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9114 - accuracy: 0.5758
# Epoch 6/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8838 - accuracy: 0.6061
# Epoch 7/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8585 - accuracy: 0.6364
# Epoch 8/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8339 - accuracy: 0.6667
# Epoch 9/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8106 - accuracy: 0.6970
# Epoch 10/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7887 - accuracy: 0.6970
# Epoch 11/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7672 - accuracy: 0.7576
# Epoch 12/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7465 - accuracy: 0.7576
# Epoch 13/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7258 - accuracy: 0.7576
# Epoch 14/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7066 - accuracy: 0.7576
# Epoch 15/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6882 - accuracy: 0.7576
# Epoch 16/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6680 - accuracy: 0.7576
# Epoch 17/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6493 - accuracy: 0.7576
# Epoch 18/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6341 - accuracy: 0.7576
# Epoch 19/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6155 - accuracy: 0.7576
# Epoch 20/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6013 - accuracy: 0.7576
# Epoch 21/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5836 - accuracy: 0.7576
# Epoch 22/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5698 - accuracy: 0.7576
# Epoch 23/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5562 - accuracy: 0.7576
# Epoch 24/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5434 - accuracy: 0.7576
# Epoch 25/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5306 - accuracy: 0.7576
# Epoch 26/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5192 - accuracy: 0.7576
# Epoch 27/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5082 - accuracy: 0.7576
# Epoch 28/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4982 - accuracy: 0.7576
# Epoch 29/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4877 - accuracy: 0.7576
# Epoch 30/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4779 - accuracy: 0.7576
# Epoch 31/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4688 - accuracy: 0.7576
# Epoch 32/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4600 - accuracy: 0.7576
# Epoch 33/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4514 - accuracy: 0.7576
# Epoch 34/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4431 - accuracy: 0.7879
# Epoch 35/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4358 - accuracy: 0.7879
# Epoch 36/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4284 - accuracy: 0.8182
# Epoch 37/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4222 - accuracy: 0.8182
# Epoch 38/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4146 - accuracy: 0.8182
# Epoch 39/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4083 - accuracy: 0.8182
# Epoch 40/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4023 - accuracy: 0.8182
# Epoch 41/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3956 - accuracy: 0.8182
# Epoch 42/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.8485
# Epoch 43/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3836 - accuracy: 0.8485
# Epoch 44/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3781 - accuracy: 0.8788
# Epoch 45/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3726 - accuracy: 0.8788
# Epoch 46/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3666 - accuracy: 0.8788
# Epoch 47/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3608 - accuracy: 0.8788
# Epoch 48/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3554 - accuracy: 0.8788
# Epoch 49/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3501 - accuracy: 0.8788
# Epoch 50/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3447 - accuracy: 0.8788
# 1/1 [==============================] - 0s 52ms/step
# Average Accuracy: 0.8578431372549019
# Average F1 Score: 0.8291446706887884
# Average Precision Score: 0.8472951680672268
# Average Recall Score: 0.8578431372549019

# %%
# Simpan model terbaik
model_path = 'best_model.h5'
best_model.save(model_path)
print(f"Model disimpan di {model_path}")

# Simpan scaler
import joblib
scaler_path = 'scaler.pkl'
joblib.dump(scaler, scaler_path)
print(f"Scaler disimpan di {scaler_path}")
# Out:
# Model disimpan di best_model.h5
# Scaler disimpan di scaler.pkl
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Evaluation Metrics
y_pred_prob = model.predict(X)
y_pred = np.argmax(y_pred_prob, axis=1)

print("Confusion Matrix:\n", confusion_matrix(y, y_pred))
print("Classification Report:\n", classification_report(y, y_pred))
print("F1 Score:", f1_score(y, y_pred, average='weighted'))
print("Precision Score:", precision_score(y, y_pred, average='weighted'))
print("Recall Score:", recall_score(y, y_pred, average='weighted'))
# Out:
# 2/2 [==============================] - 0s 4ms/step
# Confusion Matrix:
#  [[17  0  0]
#  [ 5  6  1]
#  [ 0  0 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        17
#            1       1.00      0.50      0.67        12
#            2       0.95      1.00      0.98        20
#
#     accuracy                           0.88        49
#    macro avg       0.91      0.83      0.84        49
# weighted avg       0.90      0.88      0.86        49
#
# F1 Score: 0.8639328151523273
# Precision Score: 0.9017139323261772
# Recall Score: 0.8775510204081632
